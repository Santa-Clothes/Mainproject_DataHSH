# %% [markdown]
# # Project Execution Notebook
#
# 이 노트북은 가상환경에서 프로젝트의 모듈을 로드하고 테스트하기 위해 생성되었습니다.

# %%
import os
import sys

# 프로젝트 루트 경로를 sys.path에 추가 (ldg 폴더의 상위 폴더)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

print(f"Project root added to sys.path: {project_root}")
# Out:
# Project root added to sys.path: d:\codestudy\PNU\work_mainproject\Mainproject_DataHSH

# %% [markdown]
# ## 1. 환경 확인
# 현재 가상환경이 올바르게 로드되었는지 확인합니다.

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA (GPU) available: {torch.cuda.is_available()}")
# Out:
# PyTorch version: 2.9.1+rocmsdk20260116
# CUDA (GPU) available: True

# %% [markdown]
# ## 2. 프로젝트 모듈 테스트
# `models` 패키지에서 모듈을 임포트해봅니다.

# %%
try:
    # FashionJSONEncoder 대신 JSONEncoder를 임포트합니다.
    from models.json_encoder import JSONEncoder
    print("JSONEncoder successfully imported!")
    
    # 모델 초기화 테스트 (어휘 크기 예시 전달)
    vocab_sizes = {
        'category': 10,
        'style': 10,
        'silhouette': 10,
        'material': 10,
        'detail': 10
    }
    model = JSONEncoder(vocab_sizes=vocab_sizes)
    print("Model successfully initialized!")
    
except ImportError as e:
    print(f"Import failed: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# JSONEncoder successfully imported!
# Model successfully initialized!
